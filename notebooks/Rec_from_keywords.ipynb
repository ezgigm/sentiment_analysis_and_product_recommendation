# %%
import numpy as np
import pandas as pd
from nltk.corpus import stopwords

# %%
import re
import math

# %%
from collections import Counter

# %%
import operator

# %%
def stop_clean(text):
    text = text.split()
    text_keys = [word for word in city if word not in stopwords.words('english')]
    merge_text = " ".join(text_keys)
    return merge_text

# %%
df = pd.read_csv('df_1000.csv')

# %%
df_full = pd.read_csv('df_2000.csv')

# %%
df['review_clean']
# Out:
# 0        the prince sure is an arrogant man people in m...
# 1        jaxon you sly dog you winks i sure as hell wil...
# 2        audrey i didnt like her she was a total bimbo ...
# 3        i must say jagger has some swag when it comes ...
# 4        xaviers words of romance are quite naughty i k...
#                                ...
# 27060         good story worth the read  really enjoyed it
# 27061    the book is the best a great love story and ca...
# 27062    there has been a lot of buzz about this story ...
# 27063    it is not often that the word joyful can be us...
# 27064    i have read many of marquita valentines books ...
# Name: review_clean, Length: 27065, dtype: object

# %%
stop = set(stopwords.words("english")) #setting stopwords

# %%
# taking only words which are not stopwords
df['word_without_stop'] = df['review_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
# taking only words which are not stopwords
df_full['word_without_stop'] = df_full['review_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
def cosine_similarity_of(text1, text2):
        #get words first
        first = re.compile(r"[\w']+").findall(text1)
        second = re.compile(r"[\w']+").findall(text2)

        #get dictionary with each word and count.
        vector1 = Counter(first)
        vector2 = Counter(second)

        #convert vectors to set to find common words as intersection
        common = set(vector1.keys()).intersection(set(vector2.keys()))

        dot_product = 0.0

        for i in common:
            #get amount of each common word for both vectors and multiply them then add them together.
            dot_product += vector1[i] * vector2[i]

        squared_sum_vector1 = 0.0
        squared_sum_vector2 = 0.0

        #get squared sum values of word counts from each vector.
        for i in vector1.keys():
            squared_sum_vector1 += vector1[i]**2

        for i in vector2.keys():
            squared_sum_vector2 += vector2[i]**2

        #calculate magnitude with squared sums.
        magnitude = math.sqrt(squared_sum_vector1) * math.sqrt(squared_sum_vector2)

        if not magnitude:
            return 0.0
        else:
            return float(dot_product) / magnitude

# %%
text1 = df['word_without_stop'][1]

# %%
text2 = df['word_without_stop'][2]

# %%
cosine_similarity_of(text1, text2)
# Out:
# 0.13888386569176292

# %%
def get_recommendations(df,keywords):

        score_dict = {}

        for index, row in df.iterrows():
            score_dict[index] = cosine_similarity_of(row['word_without_stop'], keywords)

        #sort cities by score and index.
        sorted_scores = sorted(score_dict.items(), key=operator.itemgetter(1), reverse=True)

        counter = 0

        #create an empty results data frame.
        resultDF = pd.DataFrame(columns=('reviewerID', 'asin', 'title','word_without_stop', 'score'))

        #get highest scored 5 cities.
        for i in sorted_scores:
            #print index and score of the city.
            #print(i[0], i[1])
            resultDF = resultDF.append({'reviewerID': df.iloc[i[0]]['reviewerID'], 
                                        'asin': df.iloc[i[0]]['asin'], 'title': df.iloc[i[0]]['title'],
                                        'word_without_stop': df.iloc[i[0]]['word_without_stop'], 
                                        'score': i[1]}, ignore_index=True)
            counter += 1

            if counter>9:
                break

#         #convert DF to json.
#         json_result = json.dumps(resultDF.to_dict('records'))
        return resultDF

# %%
keywords = "best book ever"

# %%
top_5= get_recommendations(df,keywords)
top_5
# Out:
#        reviewerID        asin  \
# 0  A1PIHRVCTCJQFL  B018RKHYMQ
# 1  A3CMIEYL0TJLC2  B01D9JB7DW
# 2  A1O2LQUYDVPOCJ  B00VPAHRLO
# 3  A3CMIEYL0TJLC2  B01FIGE8YE
# 4  A3T5H007CVA99X  B00FR30D16
# 5  A3PYB2CTKK93MG  B00EV9LSJI
# 6  A1L9WQBSQ5SEFE  B0066HBLUO
# 7   AZYERRDY2VW61  B00629ZTOU
# 8  A15EMPO8TCH2RB  B01D4RY4B6
# 9  A19LXU1TT72OKX  B01FRQ4Z8E
#
#                                                title  \
# 0  The Stocking Was Hung (The Holidays #1) - Kind...
# 1  The Alien King&#39;s Baby: Sci-fi Alien Romanc...
# 2      The Soccer Mom&#39;s Bad Boy - Kindle edition
# 3                               Beauty and the Blitz
# 4  Her Best Match: A Clean Billionaire Romance (T...
# 5  Tears of Tess (Monsters in the Dark Book 1) - ...
# 6  CAPTURING THE COWBOY&#39;S HEART - Kindle edition
# 7  Texas Secrets: The Gallaghers of Morning Star ...
# 8  You Don&#39;t Own Me: A Bad Boy Mafia Romance ...
# 9  Dietrich (Bear Shifter Dating Agency Romance) ...
#
#                                    word_without_stop     score
# 0  great christmas best years day picked book bes...  0.544331
# 1  best book wonderful time reading new author go...  0.522233
# 2  wonderful always jordan silver best sexiest wr...  0.518476
# 3   good book far ready read next one soon best book  0.500000
# 4  saw book best romance book read like romance c...  0.500000
# 5  book one best dark romances ever read love gen...  0.489898
# 6  loved book enjoyable read im going let go book...  0.473879
# 7                               love book super book  0.471405
# 8  book made cry laughed book great book get two ...  0.471405
# 9  received arc honest review best book read writ...  0.471405

# %%
top_5= get_recommendations(df_full,keywords)

# %%
top_5
# Out:
#        reviewerID        asin  \
# 0  A3CMIEYL0TJLC2  B015QBP4XU
# 1  A3CMIEYL0TJLC2  B01B52FWAY
# 2  A1PIHRVCTCJQFL  B018RKHYMQ
# 3  A2EZZ9UTFNNKRE  B00ZO50HZO
# 4  A3CMIEYL0TJLC2  B01D9JB7DW
# 5  A1O2LQUYDVPOCJ  B00VPAHRLO
# 6  A3CMIEYL0TJLC2  B01FIGE8YE
# 7  A3T5H007CVA99X  B00FR30D16
# 8  A3MQ4814P5LBTG  B018PPWK0E
# 9  A30TZBEYTQK723  B01A1E8WO0
#
#                                                title  \
# 0  Werewolf Romance: Seduced By The Alpha Wolf Bo...
# 1  THAT MAN TRILOGY: A Sexy Romantic Comedy - Kin...
# 2  The Stocking Was Hung (The Holidays #1) - Kind...
# 3  Hot &amp; Bothered (A Hostile Operations Team ...
# 4  The Alien King&#39;s Baby: Sci-fi Alien Romanc...
# 5      The Soccer Mom&#39;s Bad Boy - Kindle edition
# 6                               Beauty and the Blitz
# 7  Her Best Match: A Clean Billionaire Romance (T...
# 8  The Way Back To Me (The Way Book 1) - Kindle e...
# 9        Big Rock (Big Rock Book 1) - Kindle edition
#
#                                    word_without_stop     score
# 0  best book ever read looking great werewolf boo...  0.666667
# 1                    finally get read book best book  0.612372
# 2  great christmas best years day picked book bes...  0.544331
# 3  oh gosh best series ever loved book much rest ...  0.544331
# 4  best book wonderful time reading new author go...  0.522233
# 5  wonderful always jordan silver best sexiest wr...  0.518476
# 6   good book far ready read next one soon best book  0.500000
# 7  saw book best romance book read like romance c...  0.500000
# 8  cant find words days completing book still can...  0.495074
# 9  book ok wasnt originality book like book invol...  0.493264

# %% [markdown]
# # Rating Effect Added

# %%
def get_rating_weight(rating, q):
#         if rating > 5 or rating < 0:
#             return None
#         else:
        m = (2*q) / 5 #10 because rating varies between 0 and 10
        b = -q
        return (m*rating) + b

# %%
def calculate_final_score(cs, r):
        amount = (cs / 100) * r

        return cs + amount

# %%
def get_recommendations_rat(df,keywords):

        score_dict = {}

        for index, row in df.iterrows():
            cs_score = cosine_similarity_of(row['word_without_stop'], keywords)

            rating = row['overall']
            
            rating_contribution = get_rating_weight(rating,10)

            final_score = calculate_final_score(cs_score, rating_contribution)

            score_dict[index] = final_score
            
        #sort cities by score and index.
        sorted_scores = sorted(score_dict.items(), key=operator.itemgetter(1), reverse=True)

        counter = 0

        #create an empty results data frame.
        resultDF = pd.DataFrame(columns=('reviewerID', 'asin','title','word_without_stop','overall', 'score'))

        #get highest scored 5 cities.
        for i in sorted_scores:
            #print index and score of the city.
            #print(i[0], i[1])
            resultDF = resultDF.append({'reviewerID': df.iloc[i[0]]['reviewerID'], 'asin': df.iloc[i[0]]['asin'],
                                        'title': df.iloc[i[0]]['title'],
                                        'word_without_stop': df.iloc[i[0]]['word_without_stop'],
                                        'overall': df.iloc[i[0]]['overall'],
                                        'score': i[1]}, ignore_index=True)
            counter += 1

            if counter>9:
                break

#         #convert DF to json.
#         json_result = json.dumps(resultDF.to_dict('records'))
        return resultDF

# %%
keywords = "best book ever"

# %%
top_5= get_recommendations_rat(df,keywords)

# %%
top_5= get_recommendations_rat(df_full,keywords)
top_5
# Out:
#        reviewerID        asin  \
# 0  A3CMIEYL0TJLC2  B015QBP4XU
# 1  A3CMIEYL0TJLC2  B01B52FWAY
# 2  A1PIHRVCTCJQFL  B018RKHYMQ
# 3  A2EZZ9UTFNNKRE  B00ZO50HZO
# 4  A3CMIEYL0TJLC2  B01D9JB7DW
# 5  A1O2LQUYDVPOCJ  B00VPAHRLO
# 6  A3T5H007CVA99X  B00FR30D16
# 7  A3MQ4814P5LBTG  B018PPWK0E
# 8  A2F5K1M79GW649  B01ACB72TS
# 9  A3PYB2CTKK93MG  B00EV9LSJI
#
#                                                title  \
# 0  Werewolf Romance: Seduced By The Alpha Wolf Bo...
# 1  THAT MAN TRILOGY: A Sexy Romantic Comedy - Kin...
# 2  The Stocking Was Hung (The Holidays #1) - Kind...
# 3  Hot &amp; Bothered (A Hostile Operations Team ...
# 4  The Alien King&#39;s Baby: Sci-fi Alien Romanc...
# 5      The Soccer Mom&#39;s Bad Boy - Kindle edition
# 6  Her Best Match: A Clean Billionaire Romance (T...
# 7  The Way Back To Me (The Way Book 1) - Kindle e...
# 8  Brothers Black: Wyatt the Heartbreaker - Kindl...
# 9  Tears of Tess (Monsters in the Dark Book 1) - ...
#
#                                    word_without_stop overall     score
# 0  best book ever read looking great werewolf boo...       5  0.733333
# 1                    finally get read book best book       5  0.673610
# 2  great christmas best years day picked book bes...       5  0.598764
# 3  oh gosh best series ever loved book much rest ...       5  0.598764
# 4  best book wonderful time reading new author go...       5  0.574456
# 5  wonderful always jordan silver best sexiest wr...       5  0.570323
# 6  saw book best romance book read like romance c...       5  0.550000
# 7  cant find words days completing book still can...       5  0.544581
# 8  book book world great man like wyattthis book ...       5  0.540089
# 9  book one best dark romances ever read love gen...       5  0.538888

# %%
top_5
# Out:
#        reviewerID        asin  \
# 0  A1PIHRVCTCJQFL  B018RKHYMQ
# 1  A3CMIEYL0TJLC2  B01D9JB7DW
# 2  A1O2LQUYDVPOCJ  B00VPAHRLO
# 3  A3T5H007CVA99X  B00FR30D16
# 4  A3PYB2CTKK93MG  B00EV9LSJI
# 5  A3CMIEYL0TJLC2  B01FIGE8YE
# 6  A1L9WQBSQ5SEFE  B0066HBLUO
# 7   AZYERRDY2VW61  B00629ZTOU
# 8  A15EMPO8TCH2RB  B01D4RY4B6
# 9  A19LXU1TT72OKX  B01FRQ4Z8E
#
#                                                title  \
# 0  The Stocking Was Hung (The Holidays #1) - Kind...
# 1  The Alien King&#39;s Baby: Sci-fi Alien Romanc...
# 2      The Soccer Mom&#39;s Bad Boy - Kindle edition
# 3  Her Best Match: A Clean Billionaire Romance (T...
# 4  Tears of Tess (Monsters in the Dark Book 1) - ...
# 5                               Beauty and the Blitz
# 6  CAPTURING THE COWBOY&#39;S HEART - Kindle edition
# 7  Texas Secrets: The Gallaghers of Morning Star ...
# 8  You Don&#39;t Own Me: A Bad Boy Mafia Romance ...
# 9  Dietrich (Bear Shifter Dating Agency Romance) ...
#
#                                    word_without_stop overall     score
# 0  great christmas best years day picked book bes...       5  0.598764
# 1  best book wonderful time reading new author go...       5  0.574456
# 2  wonderful always jordan silver best sexiest wr...       5  0.570323
# 3  saw book best romance book read like romance c...       5  0.550000
# 4  book one best dark romances ever read love gen...       5  0.538888
# 5   good book far ready read next one soon best book       4  0.530000
# 6  loved book enjoyable read im going let go book...       5  0.521267
# 7                               love book super book       5  0.518545
# 8  book made cry laughed book great book get two ...       5  0.518545
# 9  received arc honest review best book read writ...       5  0.518545

# %% [markdown]
# # rating count added

# %%
def get_rating_weight_with_quantity(rating, c, T, q):
        if rating > 5 or rating < 0:
            return None
        else:
            m = (2*q) / 5 #10 because rating varies between 0 and 10
            b = -q
            val = (m*rating) + b

            M = math.exp((-T*0.68)/c)

            return val * M

# %%
def get_recommendations_rat_count(df,keywords):

        score_dict = {}

        for index, row in df.iterrows():
            cs_score = cosine_similarity_of(row['word_without_stop'], keywords)

            rating = row['overall']
            rating_count = row['Book_Count']
            threshold = 50
            
            rating_contribution = get_rating_weight_with_quantity(rating,rating_count,threshold,10)

            final_score = calculate_final_score(cs_score, rating_contribution)

            score_dict[index] = final_score
            
        #sort cities by score and index.
        sorted_scores = sorted(score_dict.items(), key=operator.itemgetter(1), reverse=True)

        counter = 0

        #create an empty results data frame.
        resultDF = pd.DataFrame(columns=('reviewerID', 'asin','title','word_without_stop','overall', 'score'))

        #get highest scored 5 cities.
        for i in sorted_scores:
            #print index and score of the city.
            #print(i[0], i[1])
            resultDF = resultDF.append({'reviewerID': df.iloc[i[0]]['reviewerID'], 'asin': df.iloc[i[0]]['asin'],
                                        'title': df.iloc[i[0]]['title'],
                                        'word_without_stop': df.iloc[i[0]]['word_without_stop'],
                                        'overall': df.iloc[i[0]]['overall'],
                                        'score': i[1]}, ignore_index=True)
            counter += 1

            if counter>9:
                break

#         #convert DF to json.
#         json_result = json.dumps(resultDF.to_dict('records'))
        return resultDF

# %%
keywords = "best book ever"
top_5= get_recommendations_rat_count(df_full,keywords)
top_5
# Out:
#        reviewerID        asin  \
# 0  A3CMIEYL0TJLC2  B015QBP4XU
# 1  A3CMIEYL0TJLC2  B01B52FWAY
# 2  A1PIHRVCTCJQFL  B018RKHYMQ
# 3  A2EZZ9UTFNNKRE  B00ZO50HZO
# 4  A3CMIEYL0TJLC2  B01D9JB7DW
# 5  A1O2LQUYDVPOCJ  B00VPAHRLO
# 6  A3T5H007CVA99X  B00FR30D16
# 7  A3PYB2CTKK93MG  B00EV9LSJI
# 8  A2F5K1M79GW649  B01ACB72TS
# 9  A3MQ4814P5LBTG  B018PPWK0E
#
#                                                title  \
# 0  Werewolf Romance: Seduced By The Alpha Wolf Bo...
# 1  THAT MAN TRILOGY: A Sexy Romantic Comedy - Kin...
# 2  The Stocking Was Hung (The Holidays #1) - Kind...
# 3  Hot &amp; Bothered (A Hostile Operations Team ...
# 4  The Alien King&#39;s Baby: Sci-fi Alien Romanc...
# 5      The Soccer Mom&#39;s Bad Boy - Kindle edition
# 6  Her Best Match: A Clean Billionaire Romance (T...
# 7  Tears of Tess (Monsters in the Dark Book 1) - ...
# 8  Brothers Black: Wyatt the Heartbreaker - Kindl...
# 9  The Way Back To Me (The Way Book 1) - Kindle e...
#
#                                    word_without_stop overall     score
# 0  best book ever read looking great werewolf boo...       5  0.714278
# 1                    finally get read book best book       5  0.659611
# 2  great christmas best years day picked book bes...       5  0.593178
# 3  oh gosh best series ever loved book much rest ...       5  0.583206
# 4  best book wonderful time reading new author go...       5  0.565557
# 5  wonderful always jordan silver best sexiest wr...       5  0.560052
# 6  saw book best romance book read like romance c...       5  0.543871
# 7  book one best dark romances ever read love gen...       5  0.536694
# 8  book book world great man like wyattthis book ...       5  0.534320
# 9  cant find words days completing book still can...       5  0.533559

# %%
keywords = "best book ever"
top_5= get_recommendations_rat_count(df,keywords)
top_5
# Out:
#        reviewerID        asin  \
# 0  A1PIHRVCTCJQFL  B018RKHYMQ
# 1  A3CMIEYL0TJLC2  B01D9JB7DW
# 2  A1O2LQUYDVPOCJ  B00VPAHRLO
# 3  A3T5H007CVA99X  B00FR30D16
# 4  A3PYB2CTKK93MG  B00EV9LSJI
# 5  A3CMIEYL0TJLC2  B01FIGE8YE
# 6  A1L9WQBSQ5SEFE  B0066HBLUO
# 7   AZYERRDY2VW61  B00629ZTOU
# 8  A34QXHSIS1IFNS  B00HWKW7K2
# 9  A15EMPO8TCH2RB  B01D4RY4B6
#
#                                                title  \
# 0  The Stocking Was Hung (The Holidays #1) - Kind...
# 1  The Alien King&#39;s Baby: Sci-fi Alien Romanc...
# 2      The Soccer Mom&#39;s Bad Boy - Kindle edition
# 3  Her Best Match: A Clean Billionaire Romance (T...
# 4  Tears of Tess (Monsters in the Dark Book 1) - ...
# 5                               Beauty and the Blitz
# 6  CAPTURING THE COWBOY&#39;S HEART - Kindle edition
# 7  Texas Secrets: The Gallaghers of Morning Star ...
# 8  Forty 2 Days (Billionaire Banker Series) - Kin...
# 9  You Don&#39;t Own Me: A Bad Boy Mafia Romance ...
#
#                                    word_without_stop overall     score
# 0  great christmas best years day picked book bes...       5  0.593178
# 1  best book wonderful time reading new author go...       5  0.565557
# 2  wonderful always jordan silver best sexiest wr...       5  0.560052
# 3  saw book best romance book read like romance c...       5  0.543871
# 4  book one best dark romances ever read love gen...       5  0.536694
# 5   good book far ready read next one soon best book       4  0.526426
# 6  loved book enjoyable read im going let go book...       5  0.515660
# 7                               love book super book       5  0.514811
# 8                    book best needed great read get       5  0.510221
# 9  book made cry laughed book great book get two ...       5  0.509621

# %% [markdown]
# # Positive Effect

# %%
def get_recommendations_rat_count_pos(df,keywords):

        score_dict = {}

        for index, row in df.iterrows():
            cs_score = cosine_similarity_of(row['word_without_stop'], keywords)

            rating = row['overall']
            rating_count = row['Book_Count']
            
            if row['positive']==True:
                pos_dif = (7-rating)/2
                pos_rat = rating + pos_dif
            else:
                pos_dif = rating/2
                pos_rat = rating-pos_dif
            
            rating_contribution =get_rating_weight_with_quantity(pos_rat,rating_count,50,10)

            final_score = calculate_final_score(cs_score, rating_contribution)

            score_dict[index] = final_score
            
        #sort cities by score and index.
        sorted_scores = sorted(score_dict.items(), key=operator.itemgetter(1), reverse=True)

        counter = 0

        #create an empty results data frame.
        resultDF = pd.DataFrame(columns=('reviewerID', 'asin','title','word_without_stop','overall', 'score'))

        #get highest scored 5 cities.
        for i in sorted_scores:
            #print index and score of the city.
            #print(i[0], i[1])
            resultDF = resultDF.append({'reviewerID': df.iloc[i[0]]['reviewerID'], 'asin': df.iloc[i[0]]['asin'],
                                        'title': df.iloc[i[0]]['title'],
                                        'word_without_stop': df.iloc[i[0]]['word_without_stop'],
                                        'overall': df.iloc[i[0]]['overall'],
                                        'score': i[1]}, ignore_index=True)
            counter += 1

            if counter>9:
                break

#         #convert DF to json.
#         json_result = json.dumps(resultDF.to_dict('records'))
        return resultDF

# %%
df['positive'] = df['overall'].apply(lambda x: True if x>=3 else False)

# %%
df_full['positive'] = df_full['overall'].apply(lambda x: True if x>=3 else False)

# %%
df_full['negative'] = df_full['overall'].apply(lambda x: True if x<3 else False)

# %%
df['negative'] = df['overall'].apply(lambda x: True if x<3 else False)

# %%
keywords = "best book ever"
top_5= get_recommendations_rat_count_pos(df_full,keywords)
top_5
# Out:
#        reviewerID        asin  \
# 0  A3CMIEYL0TJLC2  B015QBP4XU
# 1  A3CMIEYL0TJLC2  B01B52FWAY
# 2  A1PIHRVCTCJQFL  B018RKHYMQ
# 3  A2EZZ9UTFNNKRE  B00ZO50HZO
# 4  A3CMIEYL0TJLC2  B01D9JB7DW
# 5  A1O2LQUYDVPOCJ  B00VPAHRLO
# 6  A3T5H007CVA99X  B00FR30D16
# 7  A3PYB2CTKK93MG  B00EV9LSJI
# 8  A3CMIEYL0TJLC2  B01FIGE8YE
# 9  A2F5K1M79GW649  B01ACB72TS
#
#                                                title  \
# 0  Werewolf Romance: Seduced By The Alpha Wolf Bo...
# 1  THAT MAN TRILOGY: A Sexy Romantic Comedy - Kin...
# 2  The Stocking Was Hung (The Holidays #1) - Kind...
# 3  Hot &amp; Bothered (A Hostile Operations Team ...
# 4  The Alien King&#39;s Baby: Sci-fi Alien Romanc...
# 5      The Soccer Mom&#39;s Bad Boy - Kindle edition
# 6  Her Best Match: A Clean Billionaire Romance (T...
# 7  Tears of Tess (Monsters in the Dark Book 1) - ...
# 8                               Beauty and the Blitz
# 9  Brothers Black: Wyatt the Heartbreaker - Kindl...
#
#                                    word_without_stop overall     score
# 0  best book ever read looking great werewolf boo...       5  0.733323
# 1                    finally get read book best book       5  0.678507
# 2  great christmas best years day picked book bes...       5  0.612717
# 3  oh gosh best series ever loved book much rest ...       5  0.598755
# 4  best book wonderful time reading new author go...       5  0.582887
# 5  wonderful always jordan silver best sexiest wr...       5  0.576683
# 6  saw book best romance book read like romance c...       5  0.561419
# 7  book one best dark romances ever read love gen...       5  0.555412
# 8   good book far ready read next one soon best book       4  0.552851
# 9  book book world great man like wyattthis book ...       5  0.551652

# %%
keywords = "best book ever"
top_5= get_recommendations_rat_count_pos(df,keywords)
top_5
# Out:
#        reviewerID        asin  \
# 0  A1PIHRVCTCJQFL  B018RKHYMQ
# 1  A3CMIEYL0TJLC2  B01D9JB7DW
# 2  A1O2LQUYDVPOCJ  B00VPAHRLO
# 3  A3T5H007CVA99X  B00FR30D16
# 4  A3PYB2CTKK93MG  B00EV9LSJI
# 5  A3CMIEYL0TJLC2  B01FIGE8YE
# 6  A1L9WQBSQ5SEFE  B0066HBLUO
# 7   AZYERRDY2VW61  B00629ZTOU
# 8  A34QXHSIS1IFNS  B00HWKW7K2
# 9  A15EMPO8TCH2RB  B01D4RY4B6
#
#                                                title  \
# 0  The Stocking Was Hung (The Holidays #1) - Kind...
# 1  The Alien King&#39;s Baby: Sci-fi Alien Romanc...
# 2      The Soccer Mom&#39;s Bad Boy - Kindle edition
# 3  Her Best Match: A Clean Billionaire Romance (T...
# 4  Tears of Tess (Monsters in the Dark Book 1) - ...
# 5                               Beauty and the Blitz
# 6  CAPTURING THE COWBOY&#39;S HEART - Kindle edition
# 7  Texas Secrets: The Gallaghers of Morning Star ...
# 8  Forty 2 Days (Billionaire Banker Series) - Kin...
# 9  You Don&#39;t Own Me: A Bad Boy Mafia Romance ...
#
#                                    word_without_stop overall     score
# 0  great christmas best years day picked book bes...       5  0.612717
# 1  best book wonderful time reading new author go...       5  0.582887
# 2  wonderful always jordan silver best sexiest wr...       5  0.576683
# 3  saw book best romance book read like romance c...       5  0.561419
# 4  book one best dark romances ever read love gen...       5  0.555412
# 5   good book far ready read next one soon best book       4  0.552851
# 6  loved book enjoyable read im going let go book...       5  0.532372
# 7                               love book super book       5  0.532174
# 8                    book best needed great read get       5  0.525748
# 9  book made cry laughed book great book get two ...       5  0.524907
